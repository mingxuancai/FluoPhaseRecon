# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget
import torch
import torch.nn as nn
import os
import sys
import numpy as np
import scipy.io as sio
import matplotlib.pyplot as plt
from ipywidgets import interact, IntSlider
from IPython import display
from PIL import Image, ImageDraw

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device_no = 1
torch.cuda.set_device(device_no)
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from opticaltomography.forward_inner import PhaseObject3D, Multislice
from opticaltomography.loss import mse_loss, sparsity_loss, total_variation_loss
from opticaltomography.utils import showimgstack

# %%
# Units in microns
wavelength = 0.6  # fluorescence wavelength/um
# objective immersion media
n_measure = 1.33
# background refractive index, PDMS
n_b = 1.33
mag = 20  
pixel_size = 4
na = 0.6
dx = pixel_size / mag
dy = dx
dz = dx * 3

dtype = torch.float32
np_dtype = np.float32

# %%
# import known input field from matlab file
# fx_illu_list: x position ex. 0.0041
# fy_illu_list: y position ex. -0.0146
# fz_illu_list: z layer    ex. 3

"""
na_list = sio.loadmat("Dataset/na_list_3D_num50_025.mat")
fx_illu_list = na_list["na_list_3D_num50_025"][:, 0] * 0.03   #paraxial condition
fy_illu_list = na_list["na_list_3D_num50_025"][:, 1] * 0.03
fz_illu_list = na_list["na_list_3D_num50_025"][:, 2] * 0.3     #z layer at the z=0
"""


na_list = sio.loadmat("na_list_3D_rand_10.mat")
fx_illu_list = na_list["na_list_3D_rand"][:, 0] * 0.9   #paraxial condition
fy_illu_list = na_list["na_list_3D_rand"][:, 1] * 0.9
fz_illu_list = na_list["na_list_3D_rand"][:, 2] * 0     #z layer at the z=0

# %%
# initial object, type: torch.float32
phantom = torch.zeros((200, 200, 25), dtype=dtype)

# %%
# ---------------------------#
# Setup solver objects
# ---------------------------#
solver_params = dict(wavelength = wavelength, na = na, \
                     RI_measure = n_measure, sigma = 2 * np.pi * dz / wavelength,\
                     fx_illu_list = fx_illu_list, fy_illu_list = fy_illu_list, fz_illu_list = fz_illu_list, \
                     voxel_size=(dy,dx,dz), pad = True, pad_size=(50,50))
phase_obj_3d = PhaseObject3D(shape=phantom.shape, voxel_size=(dy,dx,dz), RI=n_b)
solver_obj = Multislice(phase_obj_3d=phase_obj_3d, **solver_params)
solver_obj.setScatteringMethod(model="MultiPhaseContrast")  # solver.obj._x set to zero

# %%
# ---------------------------#
# Fill in phantom
# ---------------------------#
# import the ground truth of the 3D object to generate forward measurements
phantom_coordinates = sio.loadmat("phantomPoisson_nooverlap.mat")
phantom_temp = phantom_coordinates["phantomPoisson"]
solver_obj._x[50:150, 50:150, :] = torch.from_numpy(phantom_temp) * 0.1

for i in range(25):
    solver_obj._x[:,:,i] = torch.fft.ifftshift(solver_obj._x[:,:,i])

# Show object
filled_phantom = np.array(solver_obj._x)
filled_phantom_show = np.real(filled_phantom.transpose(2, 0, 1))

f, axes = plt.subplots(1, 1, figsize=(10, 6))
frames = []


def init():
    frames.append(axes.imshow(np.real(filled_phantom.transpose(2, 0, 1)[0])))
    axes.set_title('filled in phantom')

init()

def updateFrames(i):
    frames[0].set_data(np.real(filled_phantom.transpose(2, 0, 1)[i]))

interact(updateFrames, i=IntSlider(min=0, max=99, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=99), Output()), _dom_classes=('widget-interact',…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------#
# Show forward prediction
# ---------------------------#
# forward_field_mb[0].shape

# Show forward
f, axes = plt.subplots(1, 1, figsize=(10, 6))
frames = []

def init():
    frames.append(axes.imshow(np.fft.fftshift(solver_obj._x[:, :, 0])))
    axes.set_title('filled in phantom')

init()

def updateFrames(i):
    frames[0].set_data(np.fft.fftshift(solver_obj._x[:, :, i]))

interact(updateFrames, i=IntSlider(min=0, max=24, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=24), Output()), _dom_classes=('widget-interact',…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------#
# Generate forward prediction
# ---------------------------#
forward_field_mb, fields = solver_obj.forward(obj=solver_obj._x)

# %%
"""
for i in range(25):
    solver_obj._x[:, :, i] = np.fft.fftshift(solver_obj._x[:, :, i])
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 for i in range(25):
# ----> 2     solver_obj._x[:, :, i] = np.fft.fftshift(solver_obj._x[:, :, i])
#
# TypeError: can't assign a numpy.ndarray to a torch.FloatTensor

# %%
"""
plt.figure()
# plt.imshow(solver_obj.predictSLM(0.01, 0.01, 4, obj=torch.from_numpy(output), focal_length=-4*dz,device='cpu'))
plt.imshow(solver_obj.predictSLM(0.01, 0.01, 4, obj=torch.from_numpy(output), focal_length=4*dz,device='cpu'))
plt.colorbar()
plt.title('SLM pattern')
# plt.imshow(torch.angle(solver_obj.fields_test.cpu()))
"""

# %%
"""
output = np.load('Data/0311/output_500epoch_num50_3d_z0.3_z<1=0.npy')
plt.figure()
# plt.imshow(solver_obj.predictSLM(0.01, 0.01, 4, obj=torch.from_numpy(output), focal_length=-4*dz,device='cpu'))
plt.imshow(solver_obj.predictSLM(0, 0, 18, obj=torch.from_numpy(output), focal_length=7*dz,device='cpu'))
plt.colorbar()
plt.title('SLM pattern (100, 100, 18)')
# plt.imshow(torch.angle(solver_obj.fields_test.cpu()))
"""
# Out:
# Text(0.5, 1.0, 'SLM pattern (100, 100, 18)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
output = np.load('Data/0309/output_2000epoch_num10.npy')
plt.figure()
# plt.imshow(solver_obj.predictSLM(0.01, 0.01, 4, obj=torch.from_numpy(output), focal_length=-4*dz,device='cpu'))
plt.imshow(solver_obj.predictSLM(0, 0, 18, obj=torch.from_numpy(output), focal_length=7*dz,device='cpu'))
plt.colorbar()
# plt.title('')
# plt.imshow(torch.angle(solver_obj.fields_test.cpu()))
"""
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
obj_show = np.zeros([200,200])
for i in range(25):
    obj_show += filled_phantom[:,:,i]

plt.figure()
plt.imshow(np.fft.fftshift(obj_show))
plt.title('added up all the slices of target phase object (projection)')
"""
# Out:
# Text(0.5, 1.0, 'added up all the slices of target phase object (projection)')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
# plot = forward_field_mb[0,:,104]
# plot = torch.fft.fftshift(forward_field_mb[0])[91,:]
plot = torch.fft.fftshift(torch.real(solver_obj.test_spherical[0]))
plot = plot[90,:]
plt.figure()
plt.plot(plot)
plt.title('profile along red line')
"""
# Out:
# Text(0.5, 1.0, 'profile along red line')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------#
# Show forward prediction
# ---------------------------#
# forward_field_mb[0].shape

# Show forward
f, axes = plt.subplots(1, 1, figsize=(10, 6))
frames = []

def init():
    # img = torch.fft.fftshift(torch.abs(solver_obj.test[0]))
    # frames.append(axes.imshow(torch.abs(solver_obj.test_spherical[0])))
    frames.append(axes.imshow(forward_field_mb[0]))
    axes.set_title('generated spherical wave (abs)')

init()

def updateFrames(i):
    # img = torch.fft.fftshift(torch.abs(solver_obj.test_spherical[i]))
    #frames.append(axes.imshow(img))
    frames[0].set_data(torch.fft.fftshift(forward_field_mb[i]))

interact(updateFrames, i=IntSlider(min=0, max=9, step=1, value=0))
print(torch.sum(forward_field_mb[0]))
print(forward_field_mb[0].shape)

"""
frames = []
for i in range(50):
    im = torch.fft.fftshift(forward_field_mb[i])*4*256
    im = im.numpy()
    frames.append(Image.fromarray(im))

frames_one = frames[0]
frames_one.save("Data/0313/num50_meas.gif", format="GIF", append_images=frames, save_all=True, duration=100, loop=0)
"""
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=9), Output()), _dom_classes=('widget-interact',)…
# tensor(34.5879)
# torch.Size([200, 200])
# '\nframes = []\nfor i in range(50):\n    im = torch.fft.fftshift(forward_field_mb[i])*4*256\n    im = im.numpy()\n    frames.append(Image.fromarray(im))\n\nframes_one = frames[0]\nframes_one.save("Data/0313/num50_meas.gif", format="GIF", append_images=frames, save_all=True, duration=100, loop=0)\n'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
"""
plt.clf()
img = torch.fft.fftshift(forward_field_mb[1])
plt.imshow(img)
plt.title('measurement at camera plane (log)')
plt.colorbar()
plt.show()
"""
# Out:
# "\nplt.clf()\nimg = torch.fft.fftshift(forward_field_mb[1])\nplt.imshow(img)\nplt.title('measurement at camera plane (log)')\nplt.colorbar()\nplt.show()\n"

# %%
from opticaltomography.forward_inner import PhaseObject3D, Multislice
# ---------------------------#
# Test Reconstruction
# ---------------------------#
X = torch.zeros_like(solver_obj._x, dtype=dtype, requires_grad=True, device=device)
for source_num in range(solver_obj.number_illum):
    forward_field_mb[source_num] = forward_field_mb[source_num].to(device)

n_iters = 100
learning_rate = 1e3

optimizer = torch.optim.SGD([X], lr=learning_rate, momentum=0.9)
#f = plt.figure(1)

losslist = []

for epoch in range(n_iters):
    loss = 0
    optimizer.zero_grad()
    pred_forward, _ = solver_obj.forward(obj=X, device=device)
    for source_num in range(solver_obj.number_illum):
        loss += mse_loss(pred_forward[source_num], forward_field_mb[source_num])
    loss += total_variation_loss(X, 1e-2)

    loss_save = loss.cpu().detach().numpy()
    losslist.append(loss)
    
    loss.backward()
    optimizer.step()
    with torch.no_grad():
        
        print(f'Reconstruction after iteration {epoch}, loss {loss:.4e}')
        
        """
        error_x = torch.mean(source_init[1] - source_est[1])
        error_y = torch.mean(source_init[0] - source_est[0])
        print(f'error_x {error_x:.8e}, error_y {error_y:.8e}')
        """
# Out:
# Reconstruction after iteration 0, loss 5.7347e-05
# Reconstruction after iteration 1, loss 4.2492e-05
# Reconstruction after iteration 2, loss 2.6061e-05
# Reconstruction after iteration 3, loss 1.8490e-05
# Reconstruction after iteration 4, loss 1.5032e-05
# Reconstruction after iteration 5, loss 1.4034e-05
# Reconstruction after iteration 6, loss 1.4036e-05
# Reconstruction after iteration 7, loss 1.3979e-05
# Reconstruction after iteration 8, loss 1.3157e-05
# Reconstruction after iteration 9, loss 1.2124e-05
# Reconstruction after iteration 10, loss 1.1518e-05
# Reconstruction after iteration 11, loss 1.0154e-05
# Reconstruction after iteration 12, loss 9.6211e-06
# Reconstruction after iteration 13, loss 9.3867e-06
# Reconstruction after iteration 14, loss 8.5573e-06
# Reconstruction after iteration 15, loss 7.6918e-06
# Reconstruction after iteration 16, loss 7.3968e-06
# Reconstruction after iteration 17, loss 7.0672e-06
# Reconstruction after iteration 18, loss 6.1745e-06
# Reconstruction after iteration 19, loss 5.6273e-06
# Reconstruction after iteration 20, loss 5.3520e-06
# Reconstruction after iteration 21, loss 4.9318e-06
# Reconstruction after iteration 22, loss 4.4409e-06
# Reconstruction after iteration 23, loss 4.1846e-06
# Reconstruction after iteration 24, loss 4.0147e-06
# Reconstruction after iteration 25, loss 3.7149e-06
# Reconstruction after iteration 26, loss 3.4607e-06
# Reconstruction after iteration 27, loss 3.2232e-06
# Reconstruction after iteration 28, loss 2.9589e-06
# Reconstruction after iteration 29, loss 2.7766e-06
# Reconstruction after iteration 30, loss 2.6807e-06
# Reconstruction after iteration 31, loss 2.5095e-06
# Reconstruction after iteration 32, loss 2.2915e-06
# Reconstruction after iteration 33, loss 2.1729e-06
# Reconstruction after iteration 34, loss 2.0865e-06
# Reconstruction after iteration 35, loss 1.9418e-06
# Reconstruction after iteration 36, loss 1.8094e-06
# Reconstruction after iteration 37, loss 1.7446e-06
# Reconstruction after iteration 38, loss 1.6643e-06
# Reconstruction after iteration 39, loss 1.5572e-06
# Reconstruction after iteration 40, loss 1.4830e-06
# Reconstruction after iteration 41, loss 1.4253e-06
# Reconstruction after iteration 42, loss 1.3515e-06
# Reconstruction after iteration 43, loss 1.2839e-06
# Reconstruction after iteration 44, loss 1.2390e-06
# Reconstruction after iteration 45, loss 1.1902e-06
# Reconstruction after iteration 46, loss 1.1358e-06
# Reconstruction after iteration 47, loss 1.0908e-06
# Reconstruction after iteration 48, loss 1.0475e-06
# Reconstruction after iteration 49, loss 1.0041e-06
# Reconstruction after iteration 50, loss 9.6993e-07
# Reconstruction after iteration 51, loss 9.3954e-07
# Reconstruction after iteration 52, loss 9.0243e-07
# Reconstruction after iteration 53, loss 8.6897e-07
# Reconstruction after iteration 54, loss 8.4575e-07
# Reconstruction after iteration 55, loss 8.2090e-07
# Reconstruction after iteration 56, loss 7.9179e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 20
#      18 loss = 0
#      19 optimizer.zero_grad()
# ---> 20 pred_forward, _ = solver_obj.forward(obj=X, device=device)
#      21 for source_num in range(solver_obj.number_illum):
#      22     loss += mse_loss(pred_forward[source_num], forward_field_mb[source_num])
#
# File ~/workspace/tmp/FluoPhaseRecon/opticaltomography/forward_inner.py:117, in Multislice.forward(self, obj, device)
#     115 fy_source = self.fy_illu_list[illu_idx]
#     116 fz_source_layer = self.fz_illu_list[illu_idx]
# --> 117 fields = self._forwardMeasure(fx_source, fy_source, fz_source_layer, obj=obj, device=device)
#     119 # get only absolute value of fields
#     120 forward_scattered_predict[illu_idx,:,:] = fields
#
# File ~/workspace/tmp/FluoPhaseRecon/opticaltomography/forward_inner.py:227, in Multislice._forwardMeasure(self, fx_source, fy_source, fz_source, obj, device)
#     224     u *= self.transmittance[:, :, zz]
#     226     if zz < obj.shape[2] - 1:
# --> 227         u = self._propagationAngular(u, self.slice_separation[zz], device=device)
#     229 # Refocus
#     230 if obj.shape[2] > 1:
#
# File ~/workspace/tmp/FluoPhaseRecon/opticaltomography/forward_inner.py:358, in Multislice._propagationAngular(self, field, prop_distance, test, device)
#     355 else:
#     356     field[:, :] *= torch.conj(torch.exp(self.prop_kernel_phase * torch.abs(prop_distance)))
# --> 358 field = torch.fft.ifft2(field)
#     360 return field.to(device)
#
# KeyboardInterrupt:

# %%
# ---------------------------#
# Show forward prediction
# ---------------------------#
# forward_field_mb[0].shape

# Show forward
f, axes = plt.subplots(1, 1, figsize=(10, 6))
frames = []

def init():
    frames.append(axes.imshow(X[:, :, 0].cpu().detach().numpy()))
    axes.set_title('filled in phantom')

init()

def updateFrames(i):
    frames[0].set_data(torch.fft.fftshift(X[:, :, i]).cpu().detach().numpy())

interact(updateFrames, i=IntSlider(min=0, max=24, step=1, value=0))
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=24), Output()), _dom_classes=('widget-interact',…
# <function __main__.updateFrames(i)>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
loss_show = []
for i in range(250):
    loss_show.append(losslist[i].detach().numpy())
plt.plot(loss_show)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.save('Data/0313/loss_list_500epoch_num50_bottom',loss_show)

# %%
np.save('Data/0313/output_500epoch_num50_bottom',X.cpu().detach().numpy())

# %%
np.save('Data/0311/z_500epoch_num50_z0.5_z<1=0',X.cpu().detach().numpy())

# %%
X.detach().numpy()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

xs1 = np.random.randint(30,40,100)
ys1 = np.random.randint(20,30,100)
zs1 = np.random.randint(10,20,100)
xs2 = np.random.randint(50,60,100)
ys2 = np.random.randint(30,40,100)
zs2 = np.random.randint(50,70,100)
xs3 = np.random.randint(10,30,100)
ys3 = np.random.randint(40,50,100)
zs3 = np.random.randint(40,50,100)

# 方式1：设置三维图形模式
fig = plt.figure() # 创建一个画布figure，然后在这个画布上加各种元素。
ax = Axes3D(fig) # 将画布作用于 Axes3D 对象上。

ax.scatter(xs1,ys1,zs1) # 画出(xs1,ys1,zs1)的散点图。
ax.scatter(xs2,ys2,zs2,c='r',marker='^')
ax.scatter(xs3,ys3,zs3,c='g',marker='*')

ax.set_xlabel('X label') # 画出坐标轴
ax.set_ylabel('Y label')
ax.set_zlabel('Z label')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
